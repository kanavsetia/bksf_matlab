% %%
jorwig
% Out:
% ans =
%
%          0
%     1.0000
%     2.3820
%     2.3820
%     3.3820
%     3.3820
%     4.6180
%     4.6180
%     4.7639
%     5.6180
%     5.6180
%     5.7639
%     7.0000
%     7.0000
%     7.0000
%     7.0000
%     8.0000
%     8.0000
%     8.0000
%     8.0000
%     9.2361
%     9.3820
%     9.3820
%    10.2361
%    10.3820
%    10.3820
%    11.6180
%    11.6180
%    12.6180
%    12.6180
%    14.0000
%    15.0000
%
% ...
% > In jorwig (line 153)
%   In pymat_eval (line 31)
%   In matlabserver (line 24)]

% %%
bk
% Out:
% ans =
%
%          0
%     2.0000
%     2.0000
%     4.0000
%     5.0000
%     7.0000
%     7.0000
%     9.0000

% %%
jorwig
% Out:
% ans =
%
%    -1.0000
%    -0.3166
%          0
%     0.6834
%     6.3166
%     7.0000
%     7.3166
%     8.0000
%
% ...
% > In jorwig (line 153)
%   In pymat_eval (line 31)
%   In matlabserver (line 24)]

% %%
bk
% Out:
% ans =
%
%    -0.3166
%    -0.2426
%          0
%          0
%     6.0000
%     6.3166
%     8.0000
%     8.2426
%
% ...
% > In bk (line 113)
%   In pymat_eval (line 31)
%   In matlabserver (line 24)]
